# %%
import torchlm
print(dir(torchlm.models))
# Out:
# ['__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'pipnet', 'pipnet_resnet101_10x19x32x256_aflw', 'pipnet_resnet101_10x29x32x256_cofw', 'pipnet_resnet101_10x68x32x256_300w', 'pipnet_resnet101_10x98x32x256_wflw', 'pipnet_resnet18_10x19x32x256_aflw', 'pipnet_resnet18_10x29x32x256_cofw', 'pipnet_resnet18_10x68x32x256_300w', 'pipnet_resnet18_10x98x32x256_wflw']

# %%
import torchlm

model = torchlm.models.pipnet(backbone="resnet18", pretrained=True, num_nb=10, num_lms=68, net_stride=32,
                              input_size=256, meanface_type="300w", backbone_pretrained=True)
print(dir(model))
# Out:
# /home/lmz/anaconda3/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/lmz/anaconda3/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://github.com/DefTruth/torchlm/releases/download/torchlm-0.1.6-alpha//pipnet_resnet18_10x68x32x256_300w.pth" to /home/lmz/.cache/torch/hub/checkpoints/pipnet_resnet18_10x68x32x256_300w.pth
# ---------------------------------------------------------------------------
# ...
